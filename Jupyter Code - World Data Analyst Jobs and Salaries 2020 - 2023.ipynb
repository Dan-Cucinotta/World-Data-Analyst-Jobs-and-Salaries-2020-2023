# %%
# Import libraries.
import pandas as pd
import numpy as np
import scipy.stats as stats

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load All 5 Datasets

# %%
# Loads the world dataset.
data1 = pd.read_csv('jobs_in_data.csv')

# Creates a copy of the dataset.
world_df2 = data1.copy()

# Displays the first 5 records.
world_df2.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M

# %%
# Loads the United States only dataset.
data2 = pd.read_csv(
    'Data Analyst Salaries in The USA.csv')

# Creates a copy of the dataset.
usa_df2 = data2.copy()

# Displays the first 5 records.
usa_df2.head()
# Out:
#                         Title  Min Salary  Max Salary Salary Period  \
# 0         Carbon data analyst         NaN         NaN           NaN
# 1                Data Analyst     80783.0    103333.0        Yearly
# 2  Data Reporting Analyst III     75300.0    100800.0        Yearly
# 3         Senior Data Analyst     78700.0    163400.0        Yearly
# 4        Product Data Analyst     95200.0    121000.0        Yearly
#
#                                    Company Name State Remote
# 0                                           NaN   NaN     No
# 1                             DC Public Library   NaN     No
# 2  Horizon Blue Cross Blue Shield of New Jersey   NaN     No
# 3          First American Financial Corporation    CA    Yes
# 4                             Concept Art House   NaN    Yes

# %%
# Loads the United Kingdom only dataset.
data3 = pd.read_csv('deduped-jobs.csv')

# Creates a copy of the dataset.
uk_df2 = data3.copy()

# Displays the first 5 records.
uk_df2.head()
# Out:
#    reference                    title date_posted  \
# 0   41857664     Data Science Manager  2021-01-26
# 1   41924233   Data Science Recruiter  2021-02-03
# 2   41752222        Data Science Lead  2021-01-14
# 3   41642513  Data Science Consultant  2020-12-27
# 4   41764338     Data Science Manager  2021-01-15
#
#                    date_ending                    advertiser  \
# 0  2021-03-09T23:55:00.0000000  Charles Simon Associates Ltd
# 1  2021-03-03T23:55:00.0000000                 Crone Corkill
# 2  2021-02-25T23:55:00.0000000                       Harnham
# 3  2021-02-07T23:55:00.0000000        QUINTON DAVIES LIMITED
# 4  2021-02-26T23:55:00.0000000                    Data Idols
#
#              location     city country    salary  salary_min  salary_max  \
# 0              London   Camden      GB   70000.0     70000.0     80000.0
# 1  South East England   London      GB   20000.0     20000.0     26000.0
# 2  South East England   London      GB   75000.0     75000.0     80000.0
# 3                Avon  Bristol      GB   35000.0     35000.0     65000.0
# 4  South East England   London      GB  100000.0    100000.0    120000.0
#
#   salary_frequency  salary_currency  \
# 0             YEAR              NaN
# 1             YEAR              NaN
# 2             YEAR              NaN
# 3             YEAR              NaN
# 4             YEAR              NaN
#
#                                          description
# 0  Apply now\nData Science Manager (Data, Python,...
# 1  Apply now\nData Science Recruiter - £20,000-£2...
# 2  Apply now\nDATA SCIENCE LEAD\nUP TO £80,000 + ...
# 3  Apply now\nQuinton Davies have been engaged by...
# 4  Apply now\nData Science Manager\n\nData Idols ...

# %%
# Loads the international dataset.
data4 = pd.read_csv('ds_salaries.csv')

# Creates a copy of the dataset.
int_df2 = data4.copy()

# Displays the first 5 records.
int_df2.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
# Loads the Canada only dataset.
data5 = pd.read_csv('Job_list_Canada.csv')

# Creates a copy of the dataset.
can_df2 = data5.copy()

# Displays the first 5 records.
can_df2.head()
# Out:
#                                            JobTitle                 Company  \
# 0                         Machine Learning Engineer           Boast Capital
# 1        Machine Learning Engineer (Canada, Remote)                 Diligen
# 2  Senior Machine Learning Engineer - InSight - OPS           Iron Mountain
# 3                     Jr. Machine Learning Engineer  Niricson Software Inc.
# 4                         Research Engineer, Vision                Facebook
#
#         Location                     Salary      PostDate  \
# 0   Montréal, QC                        NaN    3 days ago
# 1    Toronto, ON  $74,062 - $188,358 a year    2 days ago
# 2         Remote                        NaN   13 days ago
# 3  Vancouver, BC   $50,000 - $60,000 a year    5 days ago
# 4   Montréal, QC                        NaN  30+ days ago
#
#                                              Summary  \
# 0  Fullstack development of AI features and appli...
# 1  Experience in machine learning techniques for ...
# 2  The ML engineer works closely with multiple in...
# 3  2+ years of industry experience in ML modellin...
# 4  Experience developing machine learning algorit...
#
#                                               JobUrl
# 0  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3  https://ca.indeed.com/company/Niricson-Softwar...
# 4  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...

# %% [markdown]
# # Data Exploration

# %%
# Displays calculations of values.
world_df2.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
# Displays calculations of values.
usa_df2.describe()
# Out:
#           Min Salary     Max Salary
# count     738.000000     738.000000
# mean    69904.707358   92407.143076
# std     27360.306143   38766.509993
# min        15.000000      15.000000
# 25%     59682.500000   76725.000000
# 50%     70900.000000   92650.000000
# 75%     85600.000000  111000.000000
# max    151800.000000  245700.000000

# %%
# Displays calculations of values.
uk_df2.describe()
# Out:
#           reference         salary     salary_min     salary_max  \
# count  5.950000e+02     595.000000     595.000000     595.000000
# mean   4.178603e+07   57037.773109   57037.773109   72586.292437
# std    1.298250e+05   21730.281996   21730.281996   37994.233441
# min    4.098746e+07   10000.000000   10000.000000   10000.000000
# 25%    4.170866e+07   40000.000000   40000.000000   55000.000000
# 50%    4.179374e+07   55000.000000   55000.000000   70000.000000
# 75%    4.189485e+07   70000.000000   70000.000000   85000.000000
# max    4.195368e+07  150000.000000  150000.000000  750000.000000
#
#        salary_currency
# count              0.0
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
# Displays calculations of values.
int_df2.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
# Displays calculations of values.
can_df2.describe()
# Out:
#             JobTitle              Company     Location  \
# count           2971                 2971         2971
# unique          1421                 1030          142
# top     Data Analyst  AbCellera Biologics  Toronto, ON
# freq              96                   69          722
#
#                            Salary      PostDate  \
# count                         444          2971
# unique                        176            32
# top     $80,000 - $120,000 a year  30+ days ago
# freq                           30          1251
#
#                                                   Summary  \
# count                                                2971
# unique                                               1811
# top     At AbCellera, we’re solving tough problems and...
# freq                                                   27
#
#                                                    JobUrl
# count                                                2971
# unique                                               2133
# top     https://ca.indeed.com/rc/clk?jk=59f13e9da13b4e...
# freq                                                    7

# %%
# Displays general information.
world_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
# Displays general information.
usa_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843 entries, 0 to 842
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Title          843 non-null    object
#  1   Min Salary     738 non-null    float64
#  2   Max Salary     738 non-null    float64
#  3   Salary Period  750 non-null    object
#  4   Company Name   819 non-null    object
#  5   State          536 non-null    object
#  6   Remote         843 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 46.2+ KB

# %%
# Displays general information.
uk_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   reference         595 non-null    int64
#  1   title             595 non-null    object
#  2   date_posted       595 non-null    object
#  3   date_ending       595 non-null    object
#  4   advertiser        595 non-null    object
#  5   location          595 non-null    object
#  6   city              595 non-null    object
#  7   country           595 non-null    object
#  8   salary            595 non-null    float64
#  9   salary_min        595 non-null    float64
#  10  salary_max        595 non-null    float64
#  11  salary_frequency  595 non-null    object
#  12  salary_currency   0 non-null      float64
#  13  description       595 non-null    object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 65.2+ KB

# %%
# Displays general information.
int_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# Displays general information.
can_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2971 entries, 0 to 2970
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   JobTitle  2971 non-null   object
#  1   Company   2971 non-null   object
#  2   Location  2971 non-null   object
#  3   Salary    444 non-null    object
#  4   PostDate  2971 non-null   object
#  5   Summary   2971 non-null   object
#  6   JobUrl    2971 non-null   object
# dtypes: object(7)
# memory usage: 162.6+ KB

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Retain Only Data Analyst Jobs

# %%
# Converts all letters in the job title to 
# uppercase and displays the first 5 rows.
world_df2['job_title'] = world_df2[
    'job_title'].apply(
    lambda x: x.upper()).copy()

world_df2.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  DATA DEVOPS ENGINEER                Data Engineering
# 1       2023        DATA ARCHITECT  Data Architecture and Modeling
# 2       2023        DATA ARCHITECT  Data Architecture and Modeling
# 3       2023        DATA SCIENTIST       Data Science and Research
# 4       2023        DATA SCIENTIST       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# 0       Full-time       Hybrid          Germany            L
# 1       Full-time    In-person    United States            M
# 2       Full-time    In-person    United States            M
# 3       Full-time    In-person    United States            M
# 4       Full-time    In-person    United States            M

# %%
# Creates a copy of dataframe with rows 
# that the job title attribute 
# contains the word 'ANALYST' 
# and displays the first 5 rows.
world_df = world_df2[
    world_df2['job_title'].str.contains(
    'ANALYST')].copy()

world_df.head()
# Out:
#     work_year     job_title   job_category salary_currency  salary  \
# 15       2023  DATA ANALYST  Data Analysis             USD   95000
# 16       2023  DATA ANALYST  Data Analysis             USD   75000
# 23       2023  DATA ANALYST  Data Analysis             USD  155000
# 24       2023  DATA ANALYST  Data Analysis             USD  110000
# 41       2023  DATA ANALYST  Data Analysis             USD  176000
#
#     salary_in_usd employee_residence experience_level employment_type  \
# 15          95000      United States      Entry-level       Full-time
# 16          75000      United States      Entry-level       Full-time
# 23         155000      United States        Mid-level       Full-time
# 24         110000      United States        Mid-level       Full-time
# 41         176000      United States           Senior       Full-time
#
#    work_setting company_location company_size
# 15    In-person    United States            M
# 16    In-person    United States            M
# 23    In-person    United States            M
# 24    In-person    United States            M
# 41    In-person    United States            M

# %%
# Calculates the difference in 
# number of records removed from
# the dataframe and displays the results.
difference1 = len(world_df2) - len(world_df)

print("\n\tThere were", difference1, 
      "records removed from the dataframe\n")
# Out:
# 	There were 7742 records removed from the dataframe

# %%
# Converts all letters in the job title to 
# uppercase and displays the first 5 rows.
usa_df2['Title'] = usa_df2['Title'].apply(
    lambda x: x.upper()).copy()

usa_df2.head()
# Out:
#                         Title  Min Salary  Max Salary Salary Period  \
# 0         CARBON DATA ANALYST         NaN         NaN           NaN
# 1                DATA ANALYST     80783.0    103333.0        Yearly
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly
#
#                                    Company Name State Remote
# 0                                           NaN   NaN     No
# 1                             DC Public Library   NaN     No
# 2  Horizon Blue Cross Blue Shield of New Jersey   NaN     No
# 3          First American Financial Corporation    CA    Yes
# 4                             Concept Art House   NaN    Yes

# %%
# Creates a copy of dataframe with 
# rows that the job title attribute 
# contains the word 'ANALYST' 
# and displays the first 5 rows.
usa_df = usa_df2[
    usa_df2['Title'].str.contains(
    'ANALYST')].copy()

usa_df.head()
# Out:
#                         Title  Min Salary  Max Salary Salary Period  \
# 0         CARBON DATA ANALYST         NaN         NaN           NaN
# 1                DATA ANALYST     80783.0    103333.0        Yearly
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly
#
#                                    Company Name State Remote
# 0                                           NaN   NaN     No
# 1                             DC Public Library   NaN     No
# 2  Horizon Blue Cross Blue Shield of New Jersey   NaN     No
# 3          First American Financial Corporation    CA    Yes
# 4                             Concept Art House   NaN    Yes

# %%
# Calculates the difference in 
# number of records removed from
# the dataframe and displays the results.
difference2 = len(usa_df2) - len(usa_df)

print("\n\tThere were", difference2, 
      "records removed from the dataframe\n")
# Out:
# 	There were 7 records removed from the dataframe

# %%
# Converts all letters in the job title to 
# uppercase and displays the first 5 rows.
uk_df2['title'] = uk_df2['title'].apply(
    lambda x: x.upper()).copy()

uk_df2.head()
# Out:
#    reference                    title date_posted  \
# 0   41857664     DATA SCIENCE MANAGER  2021-01-26
# 1   41924233   DATA SCIENCE RECRUITER  2021-02-03
# 2   41752222        DATA SCIENCE LEAD  2021-01-14
# 3   41642513  DATA SCIENCE CONSULTANT  2020-12-27
# 4   41764338     DATA SCIENCE MANAGER  2021-01-15
#
#                    date_ending                    advertiser  \
# 0  2021-03-09T23:55:00.0000000  Charles Simon Associates Ltd
# 1  2021-03-03T23:55:00.0000000                 Crone Corkill
# 2  2021-02-25T23:55:00.0000000                       Harnham
# 3  2021-02-07T23:55:00.0000000        QUINTON DAVIES LIMITED
# 4  2021-02-26T23:55:00.0000000                    Data Idols
#
#              location     city country    salary  salary_min  salary_max  \
# 0              London   Camden      GB   70000.0     70000.0     80000.0
# 1  South East England   London      GB   20000.0     20000.0     26000.0
# 2  South East England   London      GB   75000.0     75000.0     80000.0
# 3                Avon  Bristol      GB   35000.0     35000.0     65000.0
# 4  South East England   London      GB  100000.0    100000.0    120000.0
#
#   salary_frequency  salary_currency  \
# 0             YEAR              NaN
# 1             YEAR              NaN
# 2             YEAR              NaN
# 3             YEAR              NaN
# 4             YEAR              NaN
#
#                                          description
# 0  Apply now\nData Science Manager (Data, Python,...
# 1  Apply now\nData Science Recruiter - £20,000-£2...
# 2  Apply now\nDATA SCIENCE LEAD\nUP TO £80,000 + ...
# 3  Apply now\nQuinton Davies have been engaged by...
# 4  Apply now\nData Science Manager\n\nData Idols ...

# %%
# Creates a copy of dataframe with 
# rows that the job title attribute 
# contains the word 'ANALYST' 
# and displays the first 5 rows.
uk_df = uk_df2[
    uk_df2['title'].str.contains(
    'ANALYST')].copy()

uk_df.head()
# Out:
#      reference                          title date_posted  \
# 77    41730933  DATA SCIENTIST / DATA ANALYST  2021-01-12
# 87    41666705                INSIGHT ANALYST  2021-01-04
# 106   41863877           PATIENT DATA ANALYST  2021-01-27
# 110   41813983         SENIOR INSIGHT ANALYST  2021-01-21
# 111   41651502         SENIOR INSIGHT ANALYST  2020-12-30
#
#                      date_ending                       advertiser  \
# 77   2021-02-23T23:55:00.0000000                Cameo Consultancy
# 87   2021-02-15T23:55:00.0000000                          Harnham
# 106  2021-03-03T23:55:00.0000000  Hyper Recruitment Solutions Ltd
# 110  2021-03-04T23:55:00.0000000                          Harnham
# 111  2021-02-10T23:55:00.0000000                          Harnham
#
#                location       city country   salary  salary_min  salary_max  \
# 77          Oxfordshire    Banbury      GB  40000.0     40000.0     42000.0
# 87       West Yorkshire      Leeds      GB  30000.0     30000.0     45000.0
# 106  South East England  Berkshire      GB  56000.0     56000.0     66000.0
# 110  South East England     London      GB  55000.0     55000.0     65000.0
# 111  South East England     London      GB  55000.0     55000.0     65000.0
#
#     salary_frequency  salary_currency  \
# 77              YEAR              NaN
# 87              YEAR              NaN
# 106             YEAR              NaN
# 110             YEAR              NaN
# 111             YEAR              NaN
#
#                                            description
# 77   Apply now\nWe are looking for a Data Scientist...
# 87   Apply now\nInsight Analyst\nLeeds\nUp to £45,0...
# 106  Apply now\nWe are currently looking for a Pati...
# 110  Apply now\nSenior Insight Analyst\nLondon\nFro...
# 111  Apply now\nSenior Insight Analyst\nLondon\nFro...

# %%
# Calculates the difference in 
# number of records removed from
# the dataframe and displays the results.
difference3 = len(uk_df2) - len(uk_df)

print("\n\tThere were", difference3, 
      "records removed from the dataframe\n")
# Out:
# 	There were 533 records removed from the dataframe

# %%
# Converts all letters in the job title to 
# uppercase and displays the first 5 rows.
int_df2['job_title'] = int_df2['job_title'].apply(
    lambda x: x.upper()).copy()

int_df2.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              DATA SCIENTIST   70000             EUR          79833
# 1  MACHINE LEARNING SCIENTIST  260000             USD         260000
# 2           BIG DATA ENGINEER   85000             GBP         109024
# 3        PRODUCT DATA ANALYST   20000             USD          20000
# 4   MACHINE LEARNING ENGINEER  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
# Creates a copy of dataframe with 
# rows that the job title attribute 
# contains the word 'ANALYST' 
# and displays the first 5 rows.
int_df = int_df2[
    int_df2['job_title'].str.contains(
    'ANALYST')].copy()

int_df.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 3            3       2020               MI              FT
# 5            5       2020               EN              FT
# 8            8       2020               MI              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
#
#                 job_title  salary salary_currency  salary_in_usd  \
# 3    PRODUCT DATA ANALYST   20000             USD          20000
# 5            DATA ANALYST   72000             USD          72000
# 8   BUSINESS DATA ANALYST  135000             USD         135000
# 13      LEAD DATA ANALYST   87000             USD          87000
# 14           DATA ANALYST   85000             USD          85000
#
#    employee_residence  remote_ratio company_location company_size
# 3                  HN             0               HN            S
# 5                  US           100               US            L
# 8                  US           100               US            L
# 13                 US           100               US            L
# 14                 US           100               US            L

# %%
# Calculates the difference in 
# number of records removed from
# the dataframe and displays the results.
difference4 = len(int_df2) -len(int_df)

print("\n\tThere were", difference4, 
      "records removed from the dataframe\n")
# Out:
# 	There were 488 records removed from the dataframe

# %%
# Converts all letters in the job title to 
# uppercase and displays the first 5 rows.
can_df2['JobTitle'] = can_df2['JobTitle'].apply(
    lambda x: x.upper()).copy()

can_df2.head()
# Out:
#                                            JobTitle                 Company  \
# 0                         MACHINE LEARNING ENGINEER           Boast Capital
# 1        MACHINE LEARNING ENGINEER (CANADA, REMOTE)                 Diligen
# 2  SENIOR MACHINE LEARNING ENGINEER - INSIGHT - OPS           Iron Mountain
# 3                     JR. MACHINE LEARNING ENGINEER  Niricson Software Inc.
# 4                         RESEARCH ENGINEER, VISION                Facebook
#
#         Location                     Salary      PostDate  \
# 0   Montréal, QC                        NaN    3 days ago
# 1    Toronto, ON  $74,062 - $188,358 a year    2 days ago
# 2         Remote                        NaN   13 days ago
# 3  Vancouver, BC   $50,000 - $60,000 a year    5 days ago
# 4   Montréal, QC                        NaN  30+ days ago
#
#                                              Summary  \
# 0  Fullstack development of AI features and appli...
# 1  Experience in machine learning techniques for ...
# 2  The ML engineer works closely with multiple in...
# 3  2+ years of industry experience in ML modellin...
# 4  Experience developing machine learning algorit...
#
#                                               JobUrl
# 0  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3  https://ca.indeed.com/company/Niricson-Softwar...
# 4  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...

# %%
# Creates a copy of dataframe with 
# rows that the job title attribute 
# contains the word 'ANALYST' 
# and displays the first 5 rows.
can_df = can_df2[
    can_df2['JobTitle'].str.contains(
    'ANALYST')].copy()

can_df.head()
# Out:
#                                  JobTitle              Company       Location  \
# 99   SENIOR STATISTICAL/ACTUARIAL ANALYST                Aviva   Montréal, QC
# 139  SENIOR STATISTICAL/ACTUARIAL ANALYST                Aviva   Montréal, QC
# 168                  COMPENSATION ANALYST  AbCellera Biologics  Vancouver, BC
# 194                  COMPENSATION ANALYST            AbCellera  Vancouver, BC
# 214         CORPORATE DEVELOPMENT ANALYST            AbCellera  Vancouver, BC
#
#     Salary     PostDate                                            Summary  \
# 99     NaN  17 days ago  You will work on the proposal of innovative ma...
# 139    NaN  17 days ago  You will work on the proposal of innovative ma...
# 168    NaN  12 days ago  Our ideal candidate is results-driven and deta...
# 194    NaN  11 days ago  Our ideal candidate is results-driven and deta...
# 214    NaN  11 days ago  Proactively developing a broad knowledge of an...
#
#                                                 JobUrl
# 99   https://ca.indeed.com/rc/clk?jk=6acfa842ec2463...
# 139  https://ca.indeed.com/rc/clk?jk=6acfa842ec2463...
# 168  https://ca.indeed.com/rc/clk?jk=fc4dac890e596e...
# 194  https://ca.indeed.com/rc/clk?jk=2043bb00716bd6...
# 214  https://ca.indeed.com/rc/clk?jk=fe46ad371b47db...

# %%
difference5 = len(can_df2) - len(can_df)

print("\n\tThere were", difference5, 
      "records removed from the dataframe\n")
# Out:
# 	There were 1733 records removed from the dataframe

# %% [markdown]
# ## Converts & Creates Uniform Columns in dataframes

# %%
# Removes all unnecessary columns from the 
# dataframe and displays the first 5 rows.
world_df.drop(world_df.columns[[2, 3, 4, 10]], 
              axis = 1, inplace = True)

world_df.head()
# Out:
#     work_year     job_title  salary_in_usd employee_residence  \
# 15       2023  DATA ANALYST          95000      United States
# 16       2023  DATA ANALYST          75000      United States
# 23       2023  DATA ANALYST         155000      United States
# 24       2023  DATA ANALYST         110000      United States
# 41       2023  DATA ANALYST         176000      United States
#
#    experience_level employment_type work_setting company_size
# 15      Entry-level       Full-time    In-person            M
# 16      Entry-level       Full-time    In-person            M
# 23        Mid-level       Full-time    In-person            M
# 24        Mid-level       Full-time    In-person            M
# 41           Senior       Full-time    In-person            M

# %%
# Creates columns and populate with data 
# based upon attributes, structure, 
# and origin of the dataframe for uniformity, 
# as well as displays the first 5 rows.
usa_df['experience_level'] = 'Mid-level'
usa_df['employee_residence'] = 'United States'
usa_df['employment_type'] = 'Full-time'
usa_df['work_year'] = '2022'

usa_df.head()
# Out:
#                         Title  Min Salary  Max Salary Salary Period  \
# 0         CARBON DATA ANALYST         NaN         NaN           NaN
# 1                DATA ANALYST     80783.0    103333.0        Yearly
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly
#
#                                    Company Name State Remote experience_level  \
# 0                                           NaN   NaN     No        Mid-level
# 1                             DC Public Library   NaN     No        Mid-level
# 2  Horizon Blue Cross Blue Shield of New Jersey   NaN     No        Mid-level
# 3          First American Financial Corporation    CA    Yes        Mid-level
# 4                             Concept Art House   NaN    Yes        Mid-level
#
#   employee_residence employment_type work_year
# 0      United States       Full-time      2022
# 1      United States       Full-time      2022
# 2      United States       Full-time      2022
# 3      United States       Full-time      2022
# 4      United States       Full-time      2022

# %%
# Renames columns to uniform names for
# merging and displays the first 5 rows.
usa_df = usa_df.rename(
    columns = {'Title':'job_title', 
              'Remote':'work_setting', 
              'State':'state', 
              'Salary Period':'salary_period'})

usa_df.head()
# Out:
#                     job_title  Min Salary  Max Salary salary_period  \
# 0         CARBON DATA ANALYST         NaN         NaN           NaN
# 1                DATA ANALYST     80783.0    103333.0        Yearly
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly
#
#                                    Company Name state work_setting  \
# 0                                           NaN   NaN           No
# 1                             DC Public Library   NaN           No
# 2  Horizon Blue Cross Blue Shield of New Jersey   NaN           No
# 3          First American Financial Corporation    CA          Yes
# 4                             Concept Art House   NaN          Yes
#
#   experience_level employee_residence employment_type work_year
# 0        Mid-level      United States       Full-time      2022
# 1        Mid-level      United States       Full-time      2022
# 2        Mid-level      United States       Full-time      2022
# 3        Mid-level      United States       Full-time      2022
# 4        Mid-level      United States       Full-time      2022

# %%
# Removes all unnecessary columns from the 
# dataframe and displays the first 5 rows.
usa_df.drop(usa_df.columns[[4]], 
            axis = 1, inplace = True)

usa_df.head()
# Out:
#                     job_title  Min Salary  Max Salary salary_period state  \
# 0         CARBON DATA ANALYST         NaN         NaN           NaN   NaN
# 1                DATA ANALYST     80783.0    103333.0        Yearly   NaN
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly   NaN
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly    CA
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly   NaN
#
#   work_setting experience_level employee_residence employment_type work_year
# 0           No        Mid-level      United States       Full-time      2022
# 1           No        Mid-level      United States       Full-time      2022
# 2           No        Mid-level      United States       Full-time      2022
# 3          Yes        Mid-level      United States       Full-time      2022
# 4          Yes        Mid-level      United States       Full-time      2022

# %%
# Creates columns and populate with data 
# based upon attributes, structure, 
# and origin of the dataframe for uniformity, 
# as well as displays the first 5 rows.
usa_df['work_setting'] = usa_df[
    'work_setting'].str.replace(
    'Yes', 'Remote').copy()

usa_df['work_setting'] = usa_df[
    'work_setting'].str.replace(
    'No','In-person').copy()

usa_df.head()
# Out:
#                     job_title  Min Salary  Max Salary salary_period state  \
# 0         CARBON DATA ANALYST         NaN         NaN           NaN   NaN
# 1                DATA ANALYST     80783.0    103333.0        Yearly   NaN
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly   NaN
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly    CA
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly   NaN
#
#   work_setting experience_level employee_residence employment_type work_year
# 0    In-person        Mid-level      United States       Full-time      2022
# 1    In-person        Mid-level      United States       Full-time      2022
# 2    In-person        Mid-level      United States       Full-time      2022
# 3       Remote        Mid-level      United States       Full-time      2022
# 4       Remote        Mid-level      United States       Full-time      2022

# %%
# Renames columns to uniform names for 
# merging and displays the first 5 rows.
uk_df = uk_df.rename(
    columns = {'title':'job_title', 
              'country':'employee_residence', 
              'date_ending':'work_year'})

uk_df.head()
# Out:
#      reference                      job_title date_posted  \
# 77    41730933  DATA SCIENTIST / DATA ANALYST  2021-01-12
# 87    41666705                INSIGHT ANALYST  2021-01-04
# 106   41863877           PATIENT DATA ANALYST  2021-01-27
# 110   41813983         SENIOR INSIGHT ANALYST  2021-01-21
# 111   41651502         SENIOR INSIGHT ANALYST  2020-12-30
#
#                        work_year                       advertiser  \
# 77   2021-02-23T23:55:00.0000000                Cameo Consultancy
# 87   2021-02-15T23:55:00.0000000                          Harnham
# 106  2021-03-03T23:55:00.0000000  Hyper Recruitment Solutions Ltd
# 110  2021-03-04T23:55:00.0000000                          Harnham
# 111  2021-02-10T23:55:00.0000000                          Harnham
#
#                location       city employee_residence   salary  salary_min  \
# 77          Oxfordshire    Banbury                 GB  40000.0     40000.0
# 87       West Yorkshire      Leeds                 GB  30000.0     30000.0
# 106  South East England  Berkshire                 GB  56000.0     56000.0
# 110  South East England     London                 GB  55000.0     55000.0
# 111  South East England     London                 GB  55000.0     55000.0
#
#      salary_max salary_frequency  salary_currency  \
# 77      42000.0             YEAR              NaN
# 87      45000.0             YEAR              NaN
# 106     66000.0             YEAR              NaN
# 110     65000.0             YEAR              NaN
# 111     65000.0             YEAR              NaN
#
#                                            description
# 77   Apply now\nWe are looking for a Data Scientist...
# 87   Apply now\nInsight Analyst\nLeeds\nUp to £45,0...
# 106  Apply now\nWe are currently looking for a Pati...
# 110  Apply now\nSenior Insight Analyst\nLondon\nFro...
# 111  Apply now\nSenior Insight Analyst\nLondon\nFro...

# %%
# Removes all unnecessary columns from the 
# dataframe and displays the first 5 rows.
uk_df.drop(uk_df.columns[
    [0, 2, 4, 5, 6, 8, 11, 12, 13]], 
    axis = 1, inplace = True)

uk_df.head()
# Out:
#                          job_title                    work_year  \
# 77   DATA SCIENTIST / DATA ANALYST  2021-02-23T23:55:00.0000000
# 87                 INSIGHT ANALYST  2021-02-15T23:55:00.0000000
# 106           PATIENT DATA ANALYST  2021-03-03T23:55:00.0000000
# 110         SENIOR INSIGHT ANALYST  2021-03-04T23:55:00.0000000
# 111         SENIOR INSIGHT ANALYST  2021-02-10T23:55:00.0000000
#
#     employee_residence  salary_min  salary_max
# 77                  GB     40000.0     42000.0
# 87                  GB     30000.0     45000.0
# 106                 GB     56000.0     66000.0
# 110                 GB     55000.0     65000.0
# 111                 GB     55000.0     65000.0

# %%
# Creates columns and populate with data 
# based upon attributes, structure, 
# and origin of the dataframe for uniformity, 
# as well as displays the first 5 rows.
uk_df['employee_residence'] = 'United Kingdom.'
uk_df['work_year'] = '2021'
uk_df['employment_type'] = 'Full-time'
uk_df['work_setting'] = 'In-person'

uk_df.head()
# Out:
#                          job_title work_year employee_residence  salary_min  \
# 77   DATA SCIENTIST / DATA ANALYST      2021    United Kingdom.     40000.0
# 87                 INSIGHT ANALYST      2021    United Kingdom.     30000.0
# 106           PATIENT DATA ANALYST      2021    United Kingdom.     56000.0
# 110         SENIOR INSIGHT ANALYST      2021    United Kingdom.     55000.0
# 111         SENIOR INSIGHT ANALYST      2021    United Kingdom.     55000.0
#
#      salary_max employment_type work_setting
# 77      42000.0       Full-time    In-person
# 87      45000.0       Full-time    In-person
# 106     66000.0       Full-time    In-person
# 110     65000.0       Full-time    In-person
# 111     65000.0       Full-time    In-person

# %%
# Renames columns to uniform names for 
# merging and displays the first 5 rows.
int_df = int_df.rename(
    columns = {'remote_ratio':
               'work_setting'}).copy()

int_df.head()
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 3            3       2020               MI              FT
# 5            5       2020               EN              FT
# 8            8       2020               MI              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
#
#                 job_title  salary salary_currency  salary_in_usd  \
# 3    PRODUCT DATA ANALYST   20000             USD          20000
# 5            DATA ANALYST   72000             USD          72000
# 8   BUSINESS DATA ANALYST  135000             USD         135000
# 13      LEAD DATA ANALYST   87000             USD          87000
# 14           DATA ANALYST   85000             USD          85000
#
#    employee_residence  work_setting company_location company_size
# 3                  HN             0               HN            S
# 5                  US           100               US            L
# 8                  US           100               US            L
# 13                 US           100               US            L
# 14                 US           100               US            L

# %%
# Removes all unnecessary columns from the 
# dataframe and displays the first 5 rows.
int_df.drop(int_df.columns[[0, 5, 6, 10]], 
            axis = 1, inplace = True)

int_df.head()
# Out:
#     work_year experience_level employment_type              job_title  \
# 3        2020               MI              FT   PRODUCT DATA ANALYST
# 5        2020               EN              FT           DATA ANALYST
# 8        2020               MI              FT  BUSINESS DATA ANALYST
# 13       2020               MI              FT      LEAD DATA ANALYST
# 14       2020               MI              FT           DATA ANALYST
#
#     salary_in_usd employee_residence  work_setting company_size
# 3           20000                 HN             0            S
# 5           72000                 US           100            L
# 8          135000                 US           100            L
# 13          87000                 US           100            L
# 14          85000                 US           100            L

# %%
# Creates a column and populates with 
# data based upon attribute, structure, 
# and origin of the dataframe, 
# as well as displays the first 5 rows.
int_df['employment_type'] = 'Full-time'

int_df.head()
# Out:
#     work_year experience_level employment_type              job_title  \
# 3        2020               MI       Full-time   PRODUCT DATA ANALYST
# 5        2020               EN       Full-time           DATA ANALYST
# 8        2020               MI       Full-time  BUSINESS DATA ANALYST
# 13       2020               MI       Full-time      LEAD DATA ANALYST
# 14       2020               MI       Full-time           DATA ANALYST
#
#     salary_in_usd employee_residence  work_setting company_size
# 3           20000                 HN             0            S
# 5           72000                 US           100            L
# 8          135000                 US           100            L
# 13          87000                 US           100            L
# 14          85000                 US           100            L

# %%
# Converts data in 'experience_level' column to uniform 
# values for merging and displays the first 5 rows.
int_df.loc[int_df['experience_level'] == 'MI', 
           'experience_level'] = 'Mid-level'
int_df.loc[int_df['experience_level'] == 'EN', 
           'experience_level'] = 'Entry-level'
int_df.loc[int_df['experience_level'] == 'EX', 
           'experience_level'] = 'Executive'
int_df.loc[int_df['experience_level'] == 'SE', 
           'experience_level'] = 'Senior'

int_df.head()
# Out:
#     work_year experience_level employment_type              job_title  \
# 3        2020        Mid-level       Full-time   PRODUCT DATA ANALYST
# 5        2020      Entry-level       Full-time           DATA ANALYST
# 8        2020        Mid-level       Full-time  BUSINESS DATA ANALYST
# 13       2020        Mid-level       Full-time      LEAD DATA ANALYST
# 14       2020        Mid-level       Full-time           DATA ANALYST
#
#     salary_in_usd employee_residence  work_setting company_size
# 3           20000                 HN             0            S
# 5           72000                 US           100            L
# 8          135000                 US           100            L
# 13          87000                 US           100            L
# 14          85000                 US           100            L

# %%
# Converts all values in the 'employee_residence' 
# column to uniform country names 
# and displays the first 5 rows.
int_df.loc[int_df['employee_residence'] == 'HN', 
           'employee_residence'] = 'Honduras'

int_df.loc[int_df['employee_residence'] == 'US', 
           'employee_residence'] = 'United States'

int_df.loc[int_df['employee_residence'] == 'PK', 
           'employee_residence'] = 'Pakistan'

int_df.loc[int_df['employee_residence'] == 'IN', 
           'employee_residence'] = 'India'

int_df.loc[int_df['employee_residence'] == 'FR', 
           'employee_residence'] = 'France'

int_df.loc[int_df['employee_residence'] == 'NG', 
           'employee_residence'] = 'Nigeria'

int_df.loc[int_df['employee_residence'] == 'BG', 
           'employee_residence'] = 'Bulgaria'

int_df.loc[int_df['employee_residence'] == 'GR', 
           'employee_residence'] = 'Greece'

int_df.loc[int_df['employee_residence'] == 'HU', 
           'employee_residence'] = 'Hungary'

int_df.loc[int_df['employee_residence'] == 'GB', 
           'employee_residence'] = 'United Kingdom'

int_df.loc[int_df['employee_residence'] == 'ES', 
           'employee_residence'] = 'Spain'

int_df.loc[int_df['employee_residence'] == 'KE', 
           'employee_residence'] = 'Kenya'

int_df.loc[int_df['employee_residence'] == 'CA', 
           'employee_residence'] = 'Canada'

int_df.loc[int_df['employee_residence'] == 'DE', 
           'employee_residence'] = 'Germany'

int_df.loc[int_df['employee_residence'] == 'LU', 
           'employee_residence'] = 'Luxembourg'

int_df.head()
# Out:
#     work_year experience_level employment_type              job_title  \
# 3        2020        Mid-level       Full-time   PRODUCT DATA ANALYST
# 5        2020      Entry-level       Full-time           DATA ANALYST
# 8        2020        Mid-level       Full-time  BUSINESS DATA ANALYST
# 13       2020        Mid-level       Full-time      LEAD DATA ANALYST
# 14       2020        Mid-level       Full-time           DATA ANALYST
#
#     salary_in_usd employee_residence  work_setting company_size
# 3           20000           Honduras             0            S
# 5           72000      United States           100            L
# 8          135000      United States           100            L
# 13          87000      United States           100            L
# 14          85000      United States           100            L

# %%
# Converts the 'work_setting' column datatype 
# to string, converts all values in the column 
# to uniform work setting values for merging 
# dataframes, and displays the first 5 rows.
int_df['work_setting'] = int_df[
    'work_setting'].astype(str).copy()

int_df.loc[int_df['work_setting'] == '0', 
           'work_setting'] = 'In-person'

int_df.loc[int_df['work_setting'] == '50', 
           'work_setting'] = 'Hybrid'

int_df.loc[int_df['work_setting'] == '100', 
           'work_setting'] = 'Remote'

int_df.head()
# Out:
#     work_year experience_level employment_type              job_title  \
# 3        2020        Mid-level       Full-time   PRODUCT DATA ANALYST
# 5        2020      Entry-level       Full-time           DATA ANALYST
# 8        2020        Mid-level       Full-time  BUSINESS DATA ANALYST
# 13       2020        Mid-level       Full-time      LEAD DATA ANALYST
# 14       2020        Mid-level       Full-time           DATA ANALYST
#
#     salary_in_usd employee_residence work_setting company_size
# 3           20000           Honduras    In-person            S
# 5           72000      United States       Remote            L
# 8          135000      United States       Remote            L
# 13          87000      United States       Remote            L
# 14          85000      United States       Remote            L

# %%
# Renames columns to uniform names for 
# merging and displays the first 5 rows.
can_df = can_df.rename(
    columns = {'JobTitle':'job_title', 
              'Location':'employee_residence', 
              'PostDate':'work_year', 
              'Salary':'salary_in_usd'})

can_df.head()
# Out:
#                                 job_title              Company  \
# 99   SENIOR STATISTICAL/ACTUARIAL ANALYST                Aviva
# 139  SENIOR STATISTICAL/ACTUARIAL ANALYST                Aviva
# 168                  COMPENSATION ANALYST  AbCellera Biologics
# 194                  COMPENSATION ANALYST            AbCellera
# 214         CORPORATE DEVELOPMENT ANALYST            AbCellera
#
#     employee_residence salary_in_usd    work_year  \
# 99        Montréal, QC           NaN  17 days ago
# 139       Montréal, QC           NaN  17 days ago
# 168      Vancouver, BC           NaN  12 days ago
# 194      Vancouver, BC           NaN  11 days ago
# 214      Vancouver, BC           NaN  11 days ago
#
#                                                Summary  \
# 99   You will work on the proposal of innovative ma...
# 139  You will work on the proposal of innovative ma...
# 168  Our ideal candidate is results-driven and deta...
# 194  Our ideal candidate is results-driven and deta...
# 214  Proactively developing a broad knowledge of an...
#
#                                                 JobUrl
# 99   https://ca.indeed.com/rc/clk?jk=6acfa842ec2463...
# 139  https://ca.indeed.com/rc/clk?jk=6acfa842ec2463...
# 168  https://ca.indeed.com/rc/clk?jk=fc4dac890e596e...
# 194  https://ca.indeed.com/rc/clk?jk=2043bb00716bd6...
# 214  https://ca.indeed.com/rc/clk?jk=fe46ad371b47db...

# %%
# Removes all unnecessary columns from the 
# dataframe and displays the first 5 rows.
can_df.drop(can_df.columns[[1, 5, 6]], 
            axis = 1, inplace = True)

can_df.head()
# Out:
#                                 job_title employee_residence salary_in_usd  \
# 99   SENIOR STATISTICAL/ACTUARIAL ANALYST       Montréal, QC           NaN
# 139  SENIOR STATISTICAL/ACTUARIAL ANALYST       Montréal, QC           NaN
# 168                  COMPENSATION ANALYST      Vancouver, BC           NaN
# 194                  COMPENSATION ANALYST      Vancouver, BC           NaN
# 214         CORPORATE DEVELOPMENT ANALYST      Vancouver, BC           NaN
#
#        work_year
# 99   17 days ago
# 139  17 days ago
# 168  12 days ago
# 194  11 days ago
# 214  11 days ago

# %%
# Creates columns and populates with data
# based upon attributes, structure, and
# origin of the dataframe for uniformity, 
# as well as displays the first 5 rows.
can_df['employee_residence'] = 'Canada'
can_df['work_year'] = '2020'
can_df['work_setting'] = 'In-person'
can_df['employment_type'] = 'Full-time'

can_df.head()
# Out:
#                                 job_title employee_residence salary_in_usd  \
# 99   SENIOR STATISTICAL/ACTUARIAL ANALYST             Canada           NaN
# 139  SENIOR STATISTICAL/ACTUARIAL ANALYST             Canada           NaN
# 168                  COMPENSATION ANALYST             Canada           NaN
# 194                  COMPENSATION ANALYST             Canada           NaN
# 214         CORPORATE DEVELOPMENT ANALYST             Canada           NaN
#
#     work_year work_setting employment_type
# 99       2020    In-person       Full-time
# 139      2020    In-person       Full-time
# 168      2020    In-person       Full-time
# 194      2020    In-person       Full-time
# 214      2020    In-person       Full-time

# %% [markdown]
# ## Drop Null Values

# %%
# Removes all null values from specified 
# columns and displays the first 5 rows.
usa_df.dropna(subset = ['Min Salary'], 
              inplace = True)

usa_df.dropna(subset = ['Max Salary'], 
              inplace = True)

usa_df.head()
# Out:
#                     job_title  Min Salary  Max Salary salary_period state  \
# 1                DATA ANALYST     80783.0    103333.0        Yearly   NaN
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly   NaN
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly    CA
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly   NaN
# 5              DATA ANALYST I     62000.0     62000.0        Yearly   NaN
#
#   work_setting experience_level employee_residence employment_type work_year
# 1    In-person        Mid-level      United States       Full-time      2022
# 2    In-person        Mid-level      United States       Full-time      2022
# 3       Remote        Mid-level      United States       Full-time      2022
# 4       Remote        Mid-level      United States       Full-time      2022
# 5    In-person        Mid-level      United States       Full-time      2022

# %%
# Removes all null values from specified 
# columns and displays the first 5 rows.
can_df.dropna(subset = ['salary_in_usd'], 
              inplace = True)

can_df.dropna(subset = ['work_year'], 
              inplace = True)

can_df.head()
# Out:
#                                              job_title employee_residence  \
# 238                                   BUSINESS ANALYST             Canada
# 250                                   BUSINESS ANALYST             Canada
# 574   SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 898                         BILINGUAL BUSINESS ANALYST             Canada
# 1132                           DATA ANALYST (CONTRACT)             Canada
#
#                  salary_in_usd work_year work_setting employment_type
# 238   $45,000 - $60,000 a year      2020    In-person       Full-time
# 250   $45,000 - $60,000 a year      2020    In-person       Full-time
# 574    $41.03 - $47.58 an hour      2020    In-person       Full-time
# 898   $45,000 - $50,000 a year      2020    In-person       Full-time
# 1132   $4,000 - $4,500 a month      2020    In-person       Full-time

# %% [markdown]
# ## Annual Salary Calculations and Conversions to U.S. Dollar

# %%
# Calculates the approximation of annual salaries for 
# various work types (full-time, part-time, contractor) 
# as well as salary periods (monthly, hourly, daily) for 
# merging dataframes and displays the first 5 rows.
usa_df.loc[usa_df['salary_period'] == 'Monthly', 
           'Min Salary'] = usa_df['Min Salary'] * 12

usa_df.loc[usa_df['salary_period'] == 'Monthly', 
           'Max Salary'] = usa_df['Max Salary'] * 12

usa_df.loc[usa_df['salary_period'] == 'Hourly', 
           'Min Salary'] = (
            usa_df['Min Salary'] * (40 * 52))

usa_df.loc[usa_df['salary_period'] == 'Hourly', 
           'Max Salary'] = (
            usa_df['Max Salary'] * (40 * 52))

usa_df.loc[usa_df['salary_period'] == 'Daily', 
           'Min Salary'] = (
            usa_df['Min Salary'] * (5 * 52))

usa_df.loc[usa_df['salary_period'] == 'Daily', 
           'Max Salary'] = (
            usa_df['Max Salary'] * (5 * 52))

usa_df.head()
# Out:
#                     job_title  Min Salary  Max Salary salary_period state  \
# 1                DATA ANALYST     80783.0    103333.0        Yearly   NaN
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly   NaN
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly    CA
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly   NaN
# 5              DATA ANALYST I     62000.0     62000.0        Yearly   NaN
#
#   work_setting experience_level employee_residence employment_type work_year
# 1    In-person        Mid-level      United States       Full-time      2022
# 2    In-person        Mid-level      United States       Full-time      2022
# 3       Remote        Mid-level      United States       Full-time      2022
# 4       Remote        Mid-level      United States       Full-time      2022
# 5    In-person        Mid-level      United States       Full-time      2022

# %%
# Calculates an average of salaries for comparative 
# analysis and displays the first 5 rows.
usa_df['salary_in_usd'] = ((usa_df['Min Salary'] + 
                            usa_df['Max Salary']) / 
                           2).astype('int').copy()

usa_df.head()
# Out:
#                     job_title  Min Salary  Max Salary salary_period state  \
# 1                DATA ANALYST     80783.0    103333.0        Yearly   NaN
# 2  DATA REPORTING ANALYST III     75300.0    100800.0        Yearly   NaN
# 3         SENIOR DATA ANALYST     78700.0    163400.0        Yearly    CA
# 4        PRODUCT DATA ANALYST     95200.0    121000.0        Yearly   NaN
# 5              DATA ANALYST I     62000.0     62000.0        Yearly   NaN
#
#   work_setting experience_level employee_residence employment_type work_year  \
# 1    In-person        Mid-level      United States       Full-time      2022
# 2    In-person        Mid-level      United States       Full-time      2022
# 3       Remote        Mid-level      United States       Full-time      2022
# 4       Remote        Mid-level      United States       Full-time      2022
# 5    In-person        Mid-level      United States       Full-time      2022
#
#    salary_in_usd
# 1          92058
# 2          88050
# 3         121050
# 4         108100
# 5          62000

# %%
# Removes all unnecessary columns from the 
# dataframe and displays the first 5 rows.
usa_df.drop(usa_df.columns[[1, 2, 3]], 
            axis = 1, inplace = True)

usa_df.head()
# Out:
#                     job_title state work_setting experience_level  \
# 1                DATA ANALYST   NaN    In-person        Mid-level
# 2  DATA REPORTING ANALYST III   NaN    In-person        Mid-level
# 3         SENIOR DATA ANALYST    CA       Remote        Mid-level
# 4        PRODUCT DATA ANALYST   NaN       Remote        Mid-level
# 5              DATA ANALYST I   NaN    In-person        Mid-level
#
#   employee_residence employment_type work_year  salary_in_usd
# 1      United States       Full-time      2022          92058
# 2      United States       Full-time      2022          88050
# 3      United States       Full-time      2022         121050
# 4      United States       Full-time      2022         108100
# 5      United States       Full-time      2022          62000

# %%
# Calculates an average of salaries for comparative 
# analysis and displays the first 5 rows.
uk_df['salary_in_usd'] = ((uk_df['salary_min'] + 
                          uk_df['salary_max']) / 2
                          ).astype('int').copy()

uk_df.head()
# Out:
#                          job_title work_year employee_residence  salary_min  \
# 77   DATA SCIENTIST / DATA ANALYST      2021    United Kingdom.     40000.0
# 87                 INSIGHT ANALYST      2021    United Kingdom.     30000.0
# 106           PATIENT DATA ANALYST      2021    United Kingdom.     56000.0
# 110         SENIOR INSIGHT ANALYST      2021    United Kingdom.     55000.0
# 111         SENIOR INSIGHT ANALYST      2021    United Kingdom.     55000.0
#
#      salary_max employment_type work_setting  salary_in_usd
# 77      42000.0       Full-time    In-person          41000
# 87      45000.0       Full-time    In-person          37500
# 106     66000.0       Full-time    In-person          61000
# 110     65000.0       Full-time    In-person          60000
# 111     65000.0       Full-time    In-person          60000

# %%
# Removes all unnecessary columns from the
# dataframe and displays the first 5 rows.
uk_df.drop(uk_df.columns[[3, 4]], 
           axis = 1, inplace = True)

uk_df.head()
# Out:
#                          job_title work_year employee_residence  \
# 77   DATA SCIENTIST / DATA ANALYST      2021    United Kingdom.
# 87                 INSIGHT ANALYST      2021    United Kingdom.
# 106           PATIENT DATA ANALYST      2021    United Kingdom.
# 110         SENIOR INSIGHT ANALYST      2021    United Kingdom.
# 111         SENIOR INSIGHT ANALYST      2021    United Kingdom.
#
#     employment_type work_setting  salary_in_usd
# 77        Full-time    In-person          41000
# 87        Full-time    In-person          37500
# 106       Full-time    In-person          61000
# 110       Full-time    In-person          60000
# 111       Full-time    In-person          60000

# %%
# Converts the currency of the British 
# Sterling Pound to the United States 
# Dollar as datatype integer for comparative 
# analysis and displays the first 5 rows.
uk_df['salary_in_usd'] = (uk_df['salary_in_usd'] *
                          1.27).astype(int).copy()

uk_df.head()
# Out:
#                          job_title work_year employee_residence  \
# 77   DATA SCIENTIST / DATA ANALYST      2021    United Kingdom.
# 87                 INSIGHT ANALYST      2021    United Kingdom.
# 106           PATIENT DATA ANALYST      2021    United Kingdom.
# 110         SENIOR INSIGHT ANALYST      2021    United Kingdom.
# 111         SENIOR INSIGHT ANALYST      2021    United Kingdom.
#
#     employment_type work_setting  salary_in_usd
# 77        Full-time    In-person          52070
# 87        Full-time    In-person          47625
# 106       Full-time    In-person          77470
# 110       Full-time    In-person          76200
# 111       Full-time    In-person          76200

# %%
# Converts all the letters in the 'salary_in_usd' 
# column to categorize for uniformity 
# and displays the first 5 rows.
can_df['salary_in_usd'] = can_df[
    'salary_in_usd'].apply(
    lambda x: x.upper()).copy()

can_df.head()
# Out:
#                                              job_title employee_residence  \
# 238                                   BUSINESS ANALYST             Canada
# 250                                   BUSINESS ANALYST             Canada
# 574   SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 898                         BILINGUAL BUSINESS ANALYST             Canada
# 1132                           DATA ANALYST (CONTRACT)             Canada
#
#                  salary_in_usd work_year work_setting employment_type
# 238   $45,000 - $60,000 A YEAR      2020    In-person       Full-time
# 250   $45,000 - $60,000 A YEAR      2020    In-person       Full-time
# 574    $41.03 - $47.58 AN HOUR      2020    In-person       Full-time
# 898   $45,000 - $50,000 A YEAR      2020    In-person       Full-time
# 1132   $4,000 - $4,500 A MONTH      2020    In-person       Full-time

# %%
# Creates a 'min_salary' value from 
# a slice of the first 8 characters. 
can_df['min_salary'] = can_df.salary_in_usd.str[:8].copy()

# Removes all unnecessary characters after 
# specified delimiters for 'min_salary'.
can_df['min_salary'] = can_df[
    'min_salary'].str.replace('$', '').copy()

can_df['min_salary'] = can_df[
    'min_salary'].str.replace('-', '').copy()

can_df['min_salary'] = can_df[
    'min_salary'].str.replace(',', '').copy()

# Creates a 'max_salary' value from a slice of characters 9 - 18. 
can_df['max_salary'] = can_df.salary_in_usd.str[9:18].copy()

# Removes all unnecessary characters after 
# specified delimiters for 'max_salary'.
can_df['max_salary'] = can_df[
    'max_salary'].str.replace('$', '').copy()

can_df['max_salary'] = can_df[
    'max_salary'].str.replace(',', '').copy()

can_df.head()
# Out:
#                                              job_title employee_residence  \
# 238                                   BUSINESS ANALYST             Canada
# 250                                   BUSINESS ANALYST             Canada
# 574   SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 898                         BILINGUAL BUSINESS ANALYST             Canada
# 1132                           DATA ANALYST (CONTRACT)             Canada
#
#                  salary_in_usd work_year work_setting employment_type  \
# 238   $45,000 - $60,000 A YEAR      2020    In-person       Full-time
# 250   $45,000 - $60,000 A YEAR      2020    In-person       Full-time
# 574    $41.03 - $47.58 AN HOUR      2020    In-person       Full-time
# 898   $45,000 - $50,000 A YEAR      2020    In-person       Full-time
# 1132   $4,000 - $4,500 A MONTH      2020    In-person       Full-time
#
#      min_salary max_salary
# 238      45000      60000
# 250      45000      60000
# 574      41.03    47.58 AN
# 898      45000      50000
# 1132      4000     4500 A

# %%
# Creates dataframes with the condition that specified salary
# period words are contained in the 'salary_in_usd' column.
yearly = can_df[
    can_df['salary_in_usd'].str.contains(
    'YEAR')].copy()

hourly = can_df[
    can_df['salary_in_usd'].str.contains(
        'HOUR')].copy()

monthly = can_df[
    can_df['salary_in_usd'].str.contains(
        'MONTH')].copy()

# %%
# Displays the first 5 rows of the yearly dataframe.
yearly.head()
# Out:
#                                           job_title employee_residence  \
# 238                                BUSINESS ANALYST             Canada
# 250                                BUSINESS ANALYST             Canada
# 898                      BILINGUAL BUSINESS ANALYST             Canada
# 1169  ANALYSTE DE DONNÉES / ANALYSTE FONCTIONNEL BI             Canada
# 1448                                   DATA ANALYST             Canada
#
#                   salary_in_usd work_year work_setting employment_type  \
# 238    $45,000 - $60,000 A YEAR      2020    In-person       Full-time
# 250    $45,000 - $60,000 A YEAR      2020    In-person       Full-time
# 898    $45,000 - $50,000 A YEAR      2020    In-person       Full-time
# 1169  $75,000 - $110,000 A YEAR      2020    In-person       Full-time
# 1448   $50,000 - $90,000 A YEAR      2020    In-person       Full-time
#
#      min_salary max_salary
# 238      45000      60000
# 250      45000      60000
# 898      45000      50000
# 1169     75000      110000
# 1448     50000      90000

# %%
# Displays the first 5 rows 
# of the hourly dataframe.
hourly.head()
# Out:
#                                              job_title employee_residence  \
# 574   SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 1316  SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 1706                ANALYSTE DE DONNÉES - DATA ANALYST             Canada
# 1708                                  DATABASE ANALYST             Canada
# 1713                ANALYSTE DE DONNÉES - DATA ANALYST             Canada
#
#                 salary_in_usd work_year work_setting employment_type  \
# 574   $41.03 - $47.58 AN HOUR      2020    In-person       Full-time
# 1316  $41.03 - $47.58 AN HOUR      2020    In-person       Full-time
# 1706        $43 - $52 AN HOUR      2020    In-person       Full-time
# 1708        $30 - $35 AN HOUR      2020    In-person       Full-time
# 1713        $43 - $52 AN HOUR      2020    In-person       Full-time
#
#      min_salary max_salary
# 574      41.03    47.58 AN
# 1316     41.03    47.58 AN
# 1706      43  5    AN HOUR
# 1708      30  3    AN HOUR
# 1713      43  5    AN HOUR

# %%
# Displays the first 5 rows 
# of the monthly dataframe.
monthly.head()
# Out:
#                           job_title employee_residence  \
# 1132        DATA ANALYST (CONTRACT)             Canada
# 1711                   DATA ANALYST             Canada
# 1730        DATA ANALYST (CONTRACT)             Canada
# 1741  TECHNICAL BUSINESS ANALYST II             Canada
# 1748  TECHNICAL BUSINESS ANALYST II             Canada
#
#                 salary_in_usd work_year work_setting employment_type  \
# 1132  $4,000 - $4,500 A MONTH      2020    In-person       Full-time
# 1711  $5,362 - $7,724 A MONTH      2020    In-person       Full-time
# 1730  $4,000 - $4,500 A MONTH      2020    In-person       Full-time
# 1741  $6,779 - $8,026 A MONTH      2020    In-person       Full-time
# 1748  $6,779 - $8,026 A MONTH      2020    In-person       Full-time
#
#      min_salary max_salary
# 1132      4000     4500 A
# 1711      5362     7724 A
# 1730      4000     4500 A
# 1741      6779     8026 A
# 1748      6779     8026 A

# %%
# Removes all unnecessary characters 
# after specified delimiters for 'min_salary'.
hourly['min_salary'] = hourly[
    'min_salary'].str.split('.').str[0].copy()

hourly['min_salary'] = hourly[
    'min_salary'].str.split('-').str[0].copy()

hourly['min_salary'] = hourly[
    'min_salary'].str.split(' ').str[0].copy()

# Removes all unnecessary characters 
# after specified delimiters for 'mAX_salary'.
hourly['max_salary'] = hourly[
    'max_salary'].str.split('.').str[0].copy()

hourly['max_salary'] = hourly[
    'max_salary'].str.split('-').str[0].copy()

hourly['max_salary'] = hourly[
    'max_salary'].str.split(' ').str[0].copy()

hourly['max_salary'] = hourly[
    'salary_in_usd'].str.split('-').str[-1].copy()

hourly['max_salary'] = hourly[
    'max_salary'].str.replace('$', '').copy()

hourly['max_salary'] = hourly[
    'max_salary'].str.rsplit('.').str[0].copy()

# Creates the 'max_salary' values to be 
# a slice from the first 3 characters.
hourly['max_salary'] = hourly.max_salary.str[:3].copy()

# Converts the datatype for both columns to integer.
hourly['min_salary'] = hourly[
    'min_salary'].astype(int).copy()

hourly['max_salary'] = hourly[
    'max_salary'].astype(int).copy()

# Calculates the approximation of an 
# annual salary for comparitive analysis.
hourly['min_salary'] = (hourly[
    'min_salary'] * (40 * 52)).copy()

hourly['max_salary'] = (hourly[
    'max_salary'] * (40 * 52)).copy()

# Displays the last 5 rows.
hourly.tail()
# Out:
#                                               job_title employee_residence  \
# 2792  SENIOR BUSINESS SYSTEMS ANALYST (CLOUD CENTRE ...             Canada
# 2804                           SYSTEMS BUSINESS ANALYST             Canada
# 2813     BUSINESS ANALYST - FUND ACCOUNTING (INVESTONE)             Canada
# 2819                           SYSTEMS BUSINESS ANALYST             Canada
# 2821     BUSINESS ANALYST - FUND ACCOUNTING (INVESTONE)             Canada
#
#                 salary_in_usd work_year work_setting employment_type  \
# 2792        $70 - $75 AN HOUR      2020    In-person       Full-time
# 2804  $47.50 - $55.00 AN HOUR      2020    In-person       Full-time
# 2813              $70 AN HOUR      2020    In-person       Full-time
# 2819  $47.50 - $55.00 AN HOUR      2020    In-person       Full-time
# 2821              $70 AN HOUR      2020    In-person       Full-time
#
#       min_salary  max_salary
# 2792      145600      156000
# 2804       97760      114400
# 2813      145600      145600
# 2819       97760      114400
# 2821      145600      145600

# %%
# Calculates the average salary and replaces 
# the values in the 'salary_in_usd' column.
hourly['salary_in_usd'] = (
    (hourly['min_salary'] + 
     hourly['max_salary']) / 2).copy()

hourly.head()
# Out:
#                                              job_title employee_residence  \
# 574   SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 1316  SENIOR ANALYST, DATA VISUALIZATION AND ANALYTICS             Canada
# 1706                ANALYSTE DE DONNÉES - DATA ANALYST             Canada
# 1708                                  DATABASE ANALYST             Canada
# 1713                ANALYSTE DE DONNÉES - DATA ANALYST             Canada
#
#       salary_in_usd work_year work_setting employment_type  min_salary  \
# 574         91520.0      2020    In-person       Full-time       85280
# 1316        91520.0      2020    In-person       Full-time       85280
# 1706        98800.0      2020    In-person       Full-time       89440
# 1708        67600.0      2020    In-person       Full-time       62400
# 1713        98800.0      2020    In-person       Full-time       89440
#
#       max_salary
# 574        97760
# 1316       97760
# 1706      108160
# 1708       72800
# 1713      108160

# %%
# Removes all unecessary remaining characters 
# after the specified space delimiter.
monthly['max_salary'] = monthly[
    'max_salary'].str.split(' ').str[0].copy()

# Converts the datatypes of both columns to integer.
monthly['min_salary'] = monthly[
    'min_salary'].astype(int).copy()

monthly['max_salary'] = monthly[
    'max_salary'].astype(int).copy()

# Calculates the approximation of an 
# annual salary for comparitive analysis.
monthly['min_salary'] = (monthly[
    'min_salary'] * 12).copy()
monthly['max_salary'] = (monthly[
    'max_salary'] * 12).copy()

# Displays the first 5 rows.
monthly.head()
# Out:
#                           job_title employee_residence  \
# 1132        DATA ANALYST (CONTRACT)             Canada
# 1711                   DATA ANALYST             Canada
# 1730        DATA ANALYST (CONTRACT)             Canada
# 1741  TECHNICAL BUSINESS ANALYST II             Canada
# 1748  TECHNICAL BUSINESS ANALYST II             Canada
#
#                 salary_in_usd work_year work_setting employment_type  \
# 1132  $4,000 - $4,500 A MONTH      2020    In-person       Full-time
# 1711  $5,362 - $7,724 A MONTH      2020    In-person       Full-time
# 1730  $4,000 - $4,500 A MONTH      2020    In-person       Full-time
# 1741  $6,779 - $8,026 A MONTH      2020    In-person       Full-time
# 1748  $6,779 - $8,026 A MONTH      2020    In-person       Full-time
#
#       min_salary  max_salary
# 1132       48000       54000
# 1711       64344       92688
# 1730       48000       54000
# 1741       81348       96312
# 1748       81348       96312

# %%
# Calculates the average salary and replaces 
# the values in the 'salary_in_usd' column.
monthly['salary_in_usd'] = (
    (monthly['min_salary'] + 
    monthly['max_salary']) / 2).copy()

# Displays the first 5 rows.
monthly.head()
# Out:
#                           job_title employee_residence  salary_in_usd  \
# 1132        DATA ANALYST (CONTRACT)             Canada        51000.0
# 1711                   DATA ANALYST             Canada        78516.0
# 1730        DATA ANALYST (CONTRACT)             Canada        51000.0
# 1741  TECHNICAL BUSINESS ANALYST II             Canada        88830.0
# 1748  TECHNICAL BUSINESS ANALYST II             Canada        88830.0
#
#      work_year work_setting employment_type  min_salary  max_salary
# 1132      2020    In-person       Full-time       48000       54000
# 1711      2020    In-person       Full-time       64344       92688
# 1730      2020    In-person       Full-time       48000       54000
# 1741      2020    In-person       Full-time       81348       96312
# 1748      2020    In-person       Full-time       81348       96312

# %%
# Converts the datatype of the 'salary_in_usd' 
# column for both dataframes to integer.
monthly['salary_in_usd'] = monthly[
    'salary_in_usd'].astype(int).copy()

hourly['salary_in_usd'] = hourly[
    'salary_in_usd'].astype(int).copy()

# %%
# Creates a dataframe from the merge
# of monthly and hourly dataframes 
# and displays the first 5 rows.
temp_df = pd.merge(monthly, hourly, 
                   how = 'outer', 
                   on = ['job_title', 
                        'employee_residence', 
                        'employment_type', 
                        'work_setting',
                        'salary_in_usd', 
                        'work_year']).copy()

temp_df.head()
# Out:
#                        job_title employee_residence  salary_in_usd work_year  \
# 0        DATA ANALYST (CONTRACT)             Canada          51000      2020
# 1        DATA ANALYST (CONTRACT)             Canada          51000      2020
# 2                   DATA ANALYST             Canada          78516      2020
# 3  TECHNICAL BUSINESS ANALYST II             Canada          88830      2020
# 4  TECHNICAL BUSINESS ANALYST II             Canada          88830      2020
#
#   work_setting employment_type  min_salary_x  max_salary_x  min_salary_y  \
# 0    In-person       Full-time       48000.0       54000.0           NaN
# 1    In-person       Full-time       48000.0       54000.0           NaN
# 2    In-person       Full-time       64344.0       92688.0           NaN
# 3    In-person       Full-time       81348.0       96312.0           NaN
# 4    In-person       Full-time       81348.0       96312.0           NaN
#
#    max_salary_y
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# Creates a dataframe with the
# condition 'YEAR' is contained 
# within the 'max_salary' column 
# and displays the first 5 rows.
yearly2 = yearly[yearly[
    'max_salary'].str.contains('YEAR')].copy()

yearly2.head()
# Out:
#                             job_title employee_residence   salary_in_usd  \
# 1494                     DATA ANALYST             Canada  $85,000 A YEAR
# 1701                     DATA ANALYST             Canada  $70,000 A YEAR
# 1707  RESEARCH ANALYST, HEALTH POLICY             Canada  $80,000 A YEAR
# 1725                     DATA ANALYST             Canada  $73,068 A YEAR
# 1726                     DATA ANALYST             Canada  $45,000 A YEAR
#
#      work_year work_setting employment_type min_salary max_salary
# 1494      2020    In-person       Full-time     85000        YEAR
# 1701      2020    In-person       Full-time     70000        YEAR
# 1707      2020    In-person       Full-time     80000        YEAR
# 1725      2020    In-person       Full-time     73068        YEAR
# 1726      2020    In-person       Full-time     45000        YEAR

# %%
# Creates a dataframe with the 
# condition 'A YEAR' is contained 
# within the 'max_salary' column 
# and displays the first 5 rows.
yearly3 = yearly[yearly[
    'max_salary'].str.contains('A YEAR')].copy()

yearly3.head()
# Out:
#                         job_title employee_residence    salary_in_usd  \
# 2808  DAX SENIOR BUSINESS ANALYST             Canada  $100,000 A YEAR
# 2822  DAX SENIOR BUSINESS ANALYST             Canada  $100,000 A YEAR
#
#      work_year work_setting employment_type min_salary max_salary
# 2808      2020    In-person       Full-time     100000     A YEAR
# 2822      2020    In-person       Full-time     100000     A YEAR

# %%
# Replaces the values in 'salary_in_usd' 
# with the previously cleaned value in 
# 'min_salary' as datatype integer.
yearly2['salary_in_usd'] = yearly2[
    'min_salary'].astype(int).copy()

# Removes all unecessary columns.
yearly2.drop(yearly2.columns[[6,7]], 
             axis = 1, inplace = True)

# Displays the first 5 rows.
yearly2.head()
# Out:
#                             job_title employee_residence  salary_in_usd  \
# 1494                     DATA ANALYST             Canada          85000
# 1701                     DATA ANALYST             Canada          70000
# 1707  RESEARCH ANALYST, HEALTH POLICY             Canada          80000
# 1725                     DATA ANALYST             Canada          73068
# 1726                     DATA ANALYST             Canada          45000
#
#      work_year work_setting employment_type
# 1494      2020    In-person       Full-time
# 1701      2020    In-person       Full-time
# 1707      2020    In-person       Full-time
# 1725      2020    In-person       Full-time
# 1726      2020    In-person       Full-time

# %%
# Replaces the values in 'salary_in_usd' 
# with the previously cleaned value in 
# 'min_salary' as datatype integer.
yearly3['salary_in_usd'] = yearly3[
    'min_salary'].astype(int).copy()

# # Removes all unecessary columns.
yearly3.drop(yearly3.columns[[6, 7]], 
             axis = 1, inplace = True)

# Displays the first 5 rows.
yearly3.head()
# Out:
#                         job_title employee_residence  salary_in_usd work_year  \
# 2808  DAX SENIOR BUSINESS ANALYST             Canada         100000      2020
# 2822  DAX SENIOR BUSINESS ANALYST             Canada         100000      2020
#
#      work_setting employment_type
# 2808    In-person       Full-time
# 2822    In-person       Full-time

# %%
# Creates a dataframe from the merge of yearly2 and 
# yearly3 dataframes and displays the first 5 rows.
yearly4 = pd.merge(
    yearly2, yearly3, 
           how = 'outer', 
           on = ['job_title',
                 'work_setting', 
                 'employment_type',                                        
                 'employee_residence', 
                 'salary_in_usd','work_year']).copy()

yearly4.head()
# Out:
#       job_title employee_residence  salary_in_usd work_year work_setting  \
# 0  DATA ANALYST             Canada          85000      2020    In-person
# 1  DATA ANALYST             Canada          70000      2020    In-person
# 2  DATA ANALYST             Canada          70000      2020    In-person
# 3  DATA ANALYST             Canada          70000      2020    In-person
# 4  DATA ANALYST             Canada          70000      2020    In-person
#
#   employment_type
# 0       Full-time
# 1       Full-time
# 2       Full-time
# 3       Full-time
# 4       Full-time

# %%
# Creates a dataframe from the merge
# of temp_df and yearly4 dataframe
# and displays the first 5 rows.
temp_df2 = pd.merge(
    temp_df, yearly4, 
            how = 'outer', 
            on = ['job_title', 
                  'employee_residence', 
                  'salary_in_usd', 
                  'work_year', 
                  'work_setting', 
                  'employment_type']).copy()

temp_df2.head()
# Out:
#                        job_title employee_residence  salary_in_usd work_year  \
# 0        DATA ANALYST (CONTRACT)             Canada          51000      2020
# 1        DATA ANALYST (CONTRACT)             Canada          51000      2020
# 2                   DATA ANALYST             Canada          78516      2020
# 3  TECHNICAL BUSINESS ANALYST II             Canada          88830      2020
# 4  TECHNICAL BUSINESS ANALYST II             Canada          88830      2020
#
#   work_setting employment_type  min_salary_x  max_salary_x  min_salary_y  \
# 0    In-person       Full-time       48000.0       54000.0           NaN
# 1    In-person       Full-time       48000.0       54000.0           NaN
# 2    In-person       Full-time       64344.0       92688.0           NaN
# 3    In-person       Full-time       81348.0       96312.0           NaN
# 4    In-person       Full-time       81348.0       96312.0           NaN
#
#    max_salary_y
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# Removes all unecessary columns 
# and displays the first 5 rows.
temp_df2.drop(
    temp_df2.columns[[6, 7, 8, 9]], 
    axis = 1, inplace = True)

temp_df2.head()
# Out:
#                        job_title employee_residence  salary_in_usd work_year  \
# 0        DATA ANALYST (CONTRACT)             Canada          51000      2020
# 1        DATA ANALYST (CONTRACT)             Canada          51000      2020
# 2                   DATA ANALYST             Canada          78516      2020
# 3  TECHNICAL BUSINESS ANALYST II             Canada          88830      2020
# 4  TECHNICAL BUSINESS ANALYST II             Canada          88830      2020
#
#   work_setting employment_type
# 0    In-person       Full-time
# 1    In-person       Full-time
# 2    In-person       Full-time
# 3    In-person       Full-time
# 4    In-person       Full-time

# %%
# Converts the Canadian Dollar to the 
# United States Dollar as datatype 
# integer for comparative analysis 
# and displays the first 5 rows.
temp_df2['salary_in_usd'] = (
    temp_df2['salary_in_usd'] 
    * .74).astype(int).copy()

temp_df2.head()
# Out:
#                        job_title employee_residence  salary_in_usd work_year  \
# 0        DATA ANALYST (CONTRACT)             Canada          37740      2020
# 1        DATA ANALYST (CONTRACT)             Canada          37740      2020
# 2                   DATA ANALYST             Canada          58101      2020
# 3  TECHNICAL BUSINESS ANALYST II             Canada          65734      2020
# 4  TECHNICAL BUSINESS ANALYST II             Canada          65734      2020
#
#   work_setting employment_type
# 0    In-person       Full-time
# 1    In-person       Full-time
# 2    In-person       Full-time
# 3    In-person       Full-time
# 4    In-person       Full-time

# %% [markdown]
# ## Clean and Merge All of the dataframes

# %%
# Creates a cleaned copy of the dataframe 
# and displays the first 5 rows.
can_df = temp_df2.copy()

can_df.head()
# Out:
#                        job_title employee_residence  salary_in_usd work_year  \
# 0        DATA ANALYST (CONTRACT)             Canada          37740      2020
# 1        DATA ANALYST (CONTRACT)             Canada          37740      2020
# 2                   DATA ANALYST             Canada          58101      2020
# 3  TECHNICAL BUSINESS ANALYST II             Canada          65734      2020
# 4  TECHNICAL BUSINESS ANALYST II             Canada          65734      2020
#
#   work_setting employment_type
# 0    In-person       Full-time
# 1    In-person       Full-time
# 2    In-person       Full-time
# 3    In-person       Full-time
# 4    In-person       Full-time

# %%
# Replaces all NaN values with
# a 0 (zero) in both dataframes 
# and displays the first 5 rows.
usa_df = usa_df.fillna(0).copy()

world_df = world_df.fillna(0).copy()

usa_df.head()
# Out:
#                     job_title state work_setting experience_level  \
# 1                DATA ANALYST     0    In-person        Mid-level
# 2  DATA REPORTING ANALYST III     0    In-person        Mid-level
# 3         SENIOR DATA ANALYST    CA       Remote        Mid-level
# 4        PRODUCT DATA ANALYST     0       Remote        Mid-level
# 5              DATA ANALYST I     0    In-person        Mid-level
#
#   employee_residence employment_type work_year  salary_in_usd
# 1      United States       Full-time      2022          92058
# 2      United States       Full-time      2022          88050
# 3      United States       Full-time      2022         121050
# 4      United States       Full-time      2022         108100
# 5      United States       Full-time      2022          62000

# %%
# Converts the 'work_year' attribute 
# datatype to an integer.
usa_df['work_year'] = usa_df[
    'work_year'].astype(int).copy()

# Creates a dataframe from the merge 
# of usa_df and world_df dataframes 
# and displays the first 5 rows.
all_df = pd.merge(
    usa_df, world_df, 
          how = 'outer', 
          on = ['job_title',
                'work_setting', 
                'salary_in_usd', 
                'work_year', 
                'employment_type', 
                'experience_level', 
                'employee_residence']).copy()

all_df.head()
# Out:
#                     job_title state work_setting experience_level  \
# 0                DATA ANALYST     0    In-person        Mid-level
# 1  DATA REPORTING ANALYST III     0    In-person        Mid-level
# 2         SENIOR DATA ANALYST    CA       Remote        Mid-level
# 3        PRODUCT DATA ANALYST     0       Remote        Mid-level
# 4              DATA ANALYST I     0    In-person        Mid-level
#
#   employee_residence employment_type  work_year  salary_in_usd company_size
# 0      United States       Full-time       2022          92058          NaN
# 1      United States       Full-time       2022          88050          NaN
# 2      United States       Full-time       2022         121050          NaN
# 3      United States       Full-time       2022         108100          NaN
# 4      United States       Full-time       2022          62000          NaN

# %%
# Converts the 'work_year' attribute datatype 
# to an integer for both dataframes for merging.
all_df['work_year'] = all_df[
    'work_year'].astype(int).copy()

uk_df['work_year'] = uk_df[
    'work_year'].astype(int).copy()

# Creates a dataframe from the merge 
# of all_df and uk_df dataframes
# and displays the first 5 rows.
all_df1 = pd.merge(
    all_df, uk_df, 
           how = 'outer', 
           on = ['job_title',
                 'work_setting', 
                 'work_year', 
                 'salary_in_usd', 
                 'employment_type', 
                 'employee_residence']).copy()

all_df1.head()
# Out:
#                     job_title state work_setting experience_level  \
# 0                DATA ANALYST     0    In-person        Mid-level
# 1  DATA REPORTING ANALYST III     0    In-person        Mid-level
# 2         SENIOR DATA ANALYST    CA       Remote        Mid-level
# 3        PRODUCT DATA ANALYST     0       Remote        Mid-level
# 4              DATA ANALYST I     0    In-person        Mid-level
#
#   employee_residence employment_type  work_year  salary_in_usd company_size
# 0      United States       Full-time       2022          92058          NaN
# 1      United States       Full-time       2022          88050          NaN
# 2      United States       Full-time       2022         121050          NaN
# 3      United States       Full-time       2022         108100          NaN
# 4      United States       Full-time       2022          62000          NaN

# %%
# Converts the 'work_year' attribute 
# datatype to an integer.
int_df['work_year'] = int_df[
    'work_year'].astype(int).copy()

# Creates a dataframe from the merge 
# of all_df1 and int_df dataframes 
# and displays the first 5 rows.
all_df2 = pd.merge(
    all_df1, int_df, 
           how = 'outer', 
           on = ['job_title',
                 'work_setting', 
                 'work_year', 
                 'experience_level', 
                 'salary_in_usd', 
                 'employment_type', 
                 'employee_residence', 
                 'company_size']).copy()

all_df2.head()
# Out:
#                     job_title state work_setting experience_level  \
# 0                DATA ANALYST     0    In-person        Mid-level
# 1  DATA REPORTING ANALYST III     0    In-person        Mid-level
# 2         SENIOR DATA ANALYST    CA       Remote        Mid-level
# 3        PRODUCT DATA ANALYST     0       Remote        Mid-level
# 4              DATA ANALYST I     0    In-person        Mid-level
#
#   employee_residence employment_type  work_year  salary_in_usd company_size
# 0      United States       Full-time       2022          92058          NaN
# 1      United States       Full-time       2022          88050          NaN
# 2      United States       Full-time       2022         121050          NaN
# 3      United States       Full-time       2022         108100          NaN
# 4      United States       Full-time       2022          62000          NaN

# %%
# Replaces all NaN values with a 0 (zero) 
# and displays the first 5 rows.
all_df2 = all_df2.replace([np.nan], 0).copy()

all_df2.head()
# Out:
#                     job_title state work_setting experience_level  \
# 0                DATA ANALYST     0    In-person        Mid-level
# 1  DATA REPORTING ANALYST III     0    In-person        Mid-level
# 2         SENIOR DATA ANALYST    CA       Remote        Mid-level
# 3        PRODUCT DATA ANALYST     0       Remote        Mid-level
# 4              DATA ANALYST I     0    In-person        Mid-level
#
#   employee_residence employment_type  work_year  salary_in_usd company_size
# 0      United States       Full-time       2022          92058            0
# 1      United States       Full-time       2022          88050            0
# 2      United States       Full-time       2022         121050            0
# 3      United States       Full-time       2022         108100            0
# 4      United States       Full-time       2022          62000            0

# %%
# Changes the values in the entire 'job_title' 
# column to Data Analyst.
all_df2['job_title'] = 'Data Analyst'

# Removes all remaining unwanted 
# characters after cleaning.
all_df2['employee_residence'] = all_df2[
    'employee_residence'].str.split(
    '.').str[0].copy()

# Removes unecessary columns and
# displays the first 5 rows.
all_df2.drop(all_df2.columns[[5]], 
             axis = 1, inplace = True)

all_df2.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size
# 0       2022          92058            0
# 1       2022          88050            0
# 2       2022         121050            0
# 3       2022         108100            0
# 4       2022          62000            0

# %% [markdown]
# ## Calculate Z-Scores

# %%
# Creates a copy of the dataframe 
# and displays the first 5 rows.
final_df = all_df2.copy()

final_df.tail()
# Out:
#          job_title state work_setting experience_level employee_residence  \
# 2477  Data Analyst     0       Remote        Mid-level             Greece
# 2478  Data Analyst     0       Remote        Mid-level              India
# 2479  Data Analyst     0       Hybrid        Mid-level             Canada
# 2480  Data Analyst     0    In-person        Mid-level     United Kingdom
# 2481  Data Analyst     0    In-person        Mid-level     United Kingdom
#
#       work_year  salary_in_usd company_size
# 2477       2022          32974            M
# 2478       2022          18442            M
# 2479       2022          70912            L
# 2480       2022          65438            M
# 2481       2022          45807            M

# %%
# Creates a copy of the dataframe 
# and displays the first 5 rows.
final_df20 = final_df.copy()

final_df20.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size
# 0       2022          92058            0
# 1       2022          88050            0
# 2       2022         121050            0
# 3       2022         108100            0
# 4       2022          62000            0

# %%
# Creates a new dataframe to calculate the job  
# count using the groupby function for employee
# residence and displays the first 5 rows
final_df21 = pd.concat([final_df20.groupby(
    'employee_residence').count()]).reset_index()

final_df21.head()
# Out:
#   employee_residence  job_title  state  work_setting  experience_level  \
# 0          Argentina          3      3             3                 3
# 1            Armenia          1      1             1                 1
# 2          Australia          5      5             5                 5
# 3             Brazil          2      2             2                 2
# 4           Bulgaria          1      1             1                 1
#
#    work_year  salary_in_usd  company_size
# 0          3              3             3
# 1          1              1             1
# 2          5              5             5
# 3          2              2             2
# 4          1              1             1

# %%
# Removes 6 unnecessary columns 
# and displays the first 5 rows.
final_df21.drop(
    final_df21.columns[[2, 3, 4, 5, 6, 7]], 
    axis = 1, inplace = True)

final_df21.head()
# Out:
#   employee_residence  job_title
# 0          Argentina          3
# 1            Armenia          1
# 2          Australia          5
# 3             Brazil          2
# 4           Bulgaria          1

# %%
# Creates a dataframe from merging 
# and displays the first 5 rows.
final_df22 = final_df20.merge(
    final_df21,
    how = 'left', 
    on = 'employee_residence' ).copy()

final_df22.head()
# Out:
#     job_title_x state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  job_title_y
# 0       2022          92058            0         2160
# 1       2022          88050            0         2160
# 2       2022         121050            0         2160
# 3       2022         108100            0         2160
# 4       2022          62000            0         2160

# %%
# Rename 2 columns and displays the first 5 rows.
final_df22 = final_df22.rename(
    columns = {'job_title_x':'job_title', 
               'job_title_y':'job_count'}).copy()

final_df22.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  job_count
# 0       2022          92058            0       2160
# 1       2022          88050            0       2160
# 2       2022         121050            0       2160
# 3       2022         108100            0       2160
# 4       2022          62000            0       2160

# %%
# Creates a column with the z-score calculation 
# values and displays the first 5 rows.
final_df22['country_job_z_score'] = stats.zscore(
    final_df22.job_count).copy()

final_df22.tail()
# Out:
#          job_title state work_setting experience_level employee_residence  \
# 2477  Data Analyst     0       Remote        Mid-level             Greece
# 2478  Data Analyst     0       Remote        Mid-level              India
# 2479  Data Analyst     0       Hybrid        Mid-level             Canada
# 2480  Data Analyst     0    In-person        Mid-level     United Kingdom
# 2481  Data Analyst     0    In-person        Mid-level     United Kingdom
#
#       work_year  salary_in_usd company_size  job_count  country_job_z_score
# 2477       2022          32974            M          6            -2.714333
# 2478       2022          18442            M          7            -2.712893
# 2479       2022          70912            L         45            -2.658202
# 2480       2022          65438            M        165            -2.485492
# 2481       2022          45807            M        165            -2.485492

# %%
# Creates a new dataframe to calculate the job  
# count using the groupby function for State
# and displays the first 5 rows
final_df23 = pd.concat(
    [final_df22.groupby('state').count()]).reset_index()

# Removes 8 unnecessary columns.
final_df23.drop(
    final_df23.columns[[2, 3, 4, 5, 6, 7, 8, 9]],
    axis = 1, inplace = True)

# Renames 2 columns and displays the first 5 rows.
final_df23.rename(columns = {'job_title':'job_count'}, 
                  inplace = True)

final_df23.head()
# Out:
#   state  job_count
# 0     0       1991
# 1    AL          3
# 2    AR          4
# 3    AZ         10
# 4    CA         71

# %%
# Creates a dataframe from valid 
# States using the .loc method.
final_df23 = final_df23.loc[
    final_df23['state'] != 0].copy()

# Calculates the state job z-score 
# and displays the first 5 rows.
final_df23['state_job_z_score'] = stats.zscore(
    final_df23.job_count).copy()

final_df23.head()
# Out:
#   state  job_count  state_job_z_score
# 1    AL          3          -0.560592
# 2    AR          4          -0.485313
# 3    AZ         10          -0.033636
# 4    CA         71           4.558416
# 5    CO          9          -0.108915

# %%
# Creates a datframe form merging
# and displays the first 5 rows.
final_df25 = final_df22.merge(
    final_df23, 
    how = 'left', 
    on = 'state').copy()

final_df25.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  job_count_x  country_job_z_score  \
# 0       2022          92058            0         2160             0.385816
# 1       2022          88050            0         2160             0.385816
# 2       2022         121050            0         2160             0.385816
# 3       2022         108100            0         2160             0.385816
# 4       2022          62000            0         2160             0.385816
#
#    job_count_y  state_job_z_score
# 0          NaN                NaN
# 1          NaN                NaN
# 2         71.0           4.558416
# 3          NaN                NaN
# 4          NaN                NaN

# %%
# Replaces all NaN values with a 0 (zero).
final_df25 = final_df25.replace(
    [np.nan], 0).copy()

# Renames the column to country_job_count.
final_df25['country_job_count'] = final_df25[
    'job_count_x'].copy()

# Renames the column to state_job_count
# and converts to datatype integer.
final_df25['state_job_count'] = final_df25[
    'job_count_y'].astype(int).copy()

# Removes 2 unnecessary columns.
final_df25.drop(final_df25.columns[[8, 10]],
                axis = 1, inplace = True)

final_df25.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  country_job_z_score  \
# 0       2022          92058            0             0.385816
# 1       2022          88050            0             0.385816
# 2       2022         121050            0             0.385816
# 3       2022         108100            0             0.385816
# 4       2022          62000            0             0.385816
#
#    state_job_z_score  country_job_count  state_job_count
# 0           0.000000               2160                0
# 1           0.000000               2160                0
# 2           4.558416               2160               71
# 3           0.000000               2160                0
# 4           0.000000               2160                0

# %%
# Makes a copy of the dataframe and 
# displays the first 5 rows.
final_df26 = final_df25.copy()

final_df26.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  country_job_z_score  \
# 0       2022          92058            0             0.385816
# 1       2022          88050            0             0.385816
# 2       2022         121050            0             0.385816
# 3       2022         108100            0             0.385816
# 4       2022          62000            0             0.385816
#
#    state_job_z_score  country_job_count  state_job_count
# 0           0.000000               2160                0
# 1           0.000000               2160                0
# 2           4.558416               2160               71
# 3           0.000000               2160                0
# 4           0.000000               2160                0

# %%
# Creates a new dataframe to 
# calculate the z-scores for 
# salaries using the groupby 
# function for State and 
# displays the first 5 rows
final_df27 = pd.concat(
    [final_df26.groupby(
    ['state', 
    'work_setting']).sum()]).reset_index()

final_df27.head()
# Out:
#   state work_setting  work_year  salary_in_usd  country_job_z_score  \
# 0     0       Hybrid      68744        2012427           -60.394928
# 1     0    In-person    2234970      114525460          -153.132209
# 2     0       Remote    1723226       90208271            24.091611
# 3    AL    In-person       2022          31200             0.385816
# 4    AL       Remote       4044         156600             0.771631
#
#    state_job_z_score  country_job_count  state_job_count
# 0           0.000000              22363                0
# 1           0.000000            1984189                0
# 2           0.000000            1628666                0
# 3          -0.560592               2160                3
# 4          -1.121185               4320                6

# %%
# Removes all unnecessary columns from the
# dataframe and displays the first 5 rows.
final_df27.drop(
    final_df27.columns[[2, 4, 5, 6, 7]], 
    axis = 1, inplace = True)

final_df27.head()
# Out:
#   state work_setting  salary_in_usd
# 0     0       Hybrid        2012427
# 1     0    In-person      114525460
# 2     0       Remote       90208271
# 3    AL    In-person          31200
# 4    AL       Remote         156600

# %%
# Creates a dataframe of valid States 
# and displays the first 5 rows.
final_df28 = final_df27[
    final_df27.state != 0]

final_df28.head()
# Out:
#   state work_setting  salary_in_usd
# 3    AL    In-person          31200
# 4    AL       Remote         156600
# 5    AR    In-person         250300
# 6    AR       Remote          52600
# 7    AZ    In-person         724650

# %%
# Makes a copy of the dataframe
# and displays the first 5 rows.
df100 = final_df28

df100.head()
# Out:
#   state work_setting  salary_in_usd
# 3    AL    In-person          31200
# 4    AL       Remote         156600
# 5    AR    In-person         250300
# 6    AR       Remote          52600
# 7    AZ    In-person         724650

# %%
# Creates a dataframe and 
# displays the first 5 rows.
dfremote = df100[
    df100.work_setting == "Remote"]

dfremote.head()
# Out:
#    state work_setting  salary_in_usd
# 4     AL       Remote         156600
# 6     AR       Remote          52600
# 8     AZ       Remote         128250
# 10    CA       Remote        2149518
# 12    CO       Remote         252738

# %%
# Creates a dataframe and 
# displays the first 5 rows.
dfinperson = df100[
    df100.work_setting == "In-person"]

dfinperson.head()
# Out:
#    state work_setting  salary_in_usd
# 3     AL    In-person          31200
# 5     AR    In-person         250300
# 7     AZ    In-person         724650
# 9     CA    In-person        4840850
# 11    CO    In-person         525148

# %%
# Calculates the z-score for each state 
# and displays the first 5 rows.
dfremote[
    'state_remote_salary_z_score'] = stats.zscore(
    dfremote.salary_in_usd).copy()

dfremote.head()
# Out:
#    state work_setting  salary_in_usd  state_remote_salary_z_score
# 4     AL       Remote         156600                    -0.463614
# 6     AR       Remote          52600                    -0.694958
# 8     AZ       Remote         128250                    -0.526677
# 10    CA       Remote        2149518                     3.969566
# 12    CO       Remote         252738                    -0.249758

# %%
# Calculates the z-score for each state 
# and displays the first 5 rows.
dfinperson[
    'state_inperson_salary_z_score'] = stats.zscore(
    dfinperson.salary_in_usd).copy()

dfinperson.head()
# Out:
#    state work_setting  salary_in_usd  state_inperson_salary_z_score
# 3     AL    In-person          31200                      -0.734369
# 5     AR    In-person         250300                      -0.493124
# 7     AZ    In-person         724650                       0.029171
# 9     CA    In-person        4840850                       4.561415
# 11    CO    In-person         525148                      -0.190495

# %%
# Creates a finalized dataframe from merging the 
# 2 dataframes and displays the first 5 rows.
df_ws = pd.merge(
    dfremote, dfinperson, 
    how = 'outer', 
    on = ['state', 
          'work_setting']).copy()

# Removes 2 unnecessary columns.
df_ws.drop(df_ws.columns[[2, 4]], 
           axis = 1, inplace = True)

df_ws.head()
# Out:
#   state work_setting  state_remote_salary_z_score  \
# 0    AL       Remote                    -0.463614
# 1    AR       Remote                    -0.694958
# 2    AZ       Remote                    -0.526677
# 3    CA       Remote                     3.969566
# 4    CO       Remote                    -0.249758
#
#    state_inperson_salary_z_score
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN

# %%
# Creates a finalized dataframe from merging the 
# 2 dataframes and displays the first 5 rows.
df_final = pd.merge(
    final_df26, df_ws, 
    how = 'left', 
    on = ['state', 
          'work_setting']).copy()

df_final.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  country_job_z_score  \
# 0       2022          92058            0             0.385816
# 1       2022          88050            0             0.385816
# 2       2022         121050            0             0.385816
# 3       2022         108100            0             0.385816
# 4       2022          62000            0             0.385816
#
#    state_job_z_score  country_job_count  state_job_count  \
# 0           0.000000               2160                0
# 1           0.000000               2160                0
# 2           4.558416               2160               71
# 3           0.000000               2160                0
# 4           0.000000               2160                0
#
#    state_remote_salary_z_score  state_inperson_salary_z_score
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                     3.969566                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN

# %%
# Creates a new dataframe to calculate the z-scores 
# for salaries using the groupby function for State
# and displays the first 5 rows
final_df29 = pd.concat(
    [final_df26.groupby(
    ['state', 
     'salary_in_usd']).sum()]).reset_index()

final_df29.tail()
# Out:
#      state  salary_in_usd  work_year  country_job_z_score  state_job_z_score  \
# 1164    WI          71140       2022             0.385816          -0.485313
# 1165    WI          78400       2022             0.385816          -0.485313
# 1166    WI          97500       2022             0.385816          -0.485313
# 1167    WY          73200       2022             0.385816          -0.635872
# 1168    WY          88850       2022             0.385816          -0.635872
#
#       country_job_count  state_job_count
# 1164               2160                4
# 1165               2160                4
# 1166               2160                4
# 1167               2160                2
# 1168               2160                2

# %%
# Removes 5 unnecessary columns.
final_df29.drop(
    final_df29.columns[[2, 3, 4, 5 ,6]], 
    axis = 1, inplace = True)

final_df29.head()
# Out:
#   state  salary_in_usd
# 0     0           6072
# 1     0           8000
# 2     0           9272
# 3     0          10000
# 4     0          10354

# %%
# Creates a dataframe of all valid States.
final_df30 = final_df29[
    final_df29.state != 0].copy()

final_df30.head()
# Out:
#     state  salary_in_usd
# 715    AL          31200
# 716    AL          62700
# 717    AL          93900
# 718    AR          52600
# 719    AR          73400

# %%
# Calculates the salary z-score for each state.
final_df30['state_salary_z_score'] = stats.zscore(
    final_df.salary_in_usd).copy()

final_df30.head()
# Out:
#     state  salary_in_usd  state_salary_z_score
# 715    AL          31200             -0.019920
# 716    AL          62700             -0.098118
# 717    AL          93900             -0.501325
# 718    AR          52600             -0.374254
# 719    AR          73400              0.239109

# %% [markdown]
# ## Create a Finalized Copy of the dataframe and a .csv file

# %%
# Creates a finalized dataframe from merging the 
# 2 dataframes and displays the first 5 rows.
finaldf = pd.merge(
    df_final, final_df30, 
    how = 'left', 
    on = ['state', 'salary_in_usd']).copy()

finaldf.head()
# Out:
#       job_title state work_setting experience_level employee_residence  \
# 0  Data Analyst     0    In-person        Mid-level      United States
# 1  Data Analyst     0    In-person        Mid-level      United States
# 2  Data Analyst    CA       Remote        Mid-level      United States
# 3  Data Analyst     0       Remote        Mid-level      United States
# 4  Data Analyst     0    In-person        Mid-level      United States
#
#    work_year  salary_in_usd company_size  country_job_z_score  \
# 0       2022          92058            0             0.385816
# 1       2022          88050            0             0.385816
# 2       2022         121050            0             0.385816
# 3       2022         108100            0             0.385816
# 4       2022          62000            0             0.385816
#
#    state_job_z_score  country_job_count  state_job_count  \
# 0           0.000000               2160                0
# 1           0.000000               2160                0
# 2           4.558416               2160               71
# 3           0.000000               2160                0
# 4           0.000000               2160                0
#
#    state_remote_salary_z_score  state_inperson_salary_z_score  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                     3.969566                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#    state_salary_z_score
# 0                   NaN
# 1                   NaN
# 2             -0.623509
# 3                   NaN
# 4                   NaN

# %%
# Creates a .csv file
finaldf.to_csv(
    'World Data Analyst Jobs and Salaries 2020 - 2023.csv')

# %%
# Basic description of the dataframe.
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2482 entries, 0 to 2481
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   job_title                      2482 non-null   object
#  1   state                          2482 non-null   object
#  2   work_setting                   2482 non-null   object
#  3   experience_level               2482 non-null   object
#  4   employee_residence             2482 non-null   object
#  5   work_year                      2482 non-null   int32
#  6   salary_in_usd                  2482 non-null   int64
#  7   company_size                   2482 non-null   object
#  8   country_job_z_score            2482 non-null   float64
#  9   state_job_z_score              2482 non-null   float64
#  10  country_job_count              2482 non-null   int64
#  11  state_job_count                2482 non-null   int32
#  12  state_remote_salary_z_score    125 non-null    float64
#  13  state_inperson_salary_z_score  366 non-null    float64
#  14  state_salary_z_score           491 non-null    float64
# dtypes: float64(5), int32(2), int64(2), object(6)
# memory usage: 290.9+ KB
